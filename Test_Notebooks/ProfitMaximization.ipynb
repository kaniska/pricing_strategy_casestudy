# %%
# !pip install pulp
# Out:
# Requirement already satisfied: pulp in /opt/conda/lib/python3.7/site-packages (2.4)
# Requirement already satisfied: amply>=0.1.2 in /opt/conda/lib/python3.7/site-packages (from pulp) (0.1.4)
# Requirement already satisfied: docutils>=0.3 in /opt/conda/lib/python3.7/site-packages (from amply>=0.1.2->pulp) (0.16)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.7/site-packages (from amply>=0.1.2->pulp) (2.4.7)

# %%
import pandas as pd
from pulp import *
import numpy as np

# %%
df = pd.read_csv("product_sales.csv")

# %%
df.head()
# Out:
#    item_id  unit_price  unit_cost  units_sold  incr_cvr  incr_sales
# 0        1          95         92         0.6     0.323     0.08906
# 1        2          37         27         0.8     0.106     0.01991
# 2        3          34         26         0.6     0.328     0.03778
# 3        4          32         30         0.7     0.000     0.08562
# 4        5          62         45         1.0     0.079     0.02637

# %%
df['profit'] = df['units_sold']*(df['unit_price']-df['unit_cost'])*(1-df['incr_cvr'])*(1-df['incr_sales'])*100
df.head()
# Out:
#    item_id  unit_price  unit_cost  units_sold  incr_cvr  incr_sales  \
# 0        1          95         92         0.6     0.323     0.08906
# 1        2          37         27         0.8     0.106     0.01991
# 2        3          34         26         0.6     0.328     0.03778
# 3        4          32         30         0.7     0.000     0.08562
# 4        5          62         45         1.0     0.079     0.02637
#
#         profit
# 0   111.007148
# 1   700.960368
# 2   310.373683
# 3   128.013200
# 4  1524.412491

# %%
df[df['item_id']==100]
# Out:
#     item_id  unit_price  unit_cost  units_sold  incr_cvr  incr_sales  \
# 99      100          66         53         2.0     0.401     0.04617
#
#          profit
# 99  1485.494842

# %%
np.sum(df['units_sold']*(df['unit_price']-df['unit_cost']))
# Out:
# 3285.9

# %%
products = list(df['item_id'])

volumes = dict(zip(products,df['units_sold']))
price = dict(zip(products,df['unit_price']))
cost = dict(zip(products,df['unit_cost']))
incr_cvr = dict(zip(products,df['incr_cvr']))
incr_sales = dict(zip(products,df['incr_sales']))

df['price_change_val'] = 0.199
price_change_val = df['price_change_val']
price_change_multiplier = 1 + price_change_val
adjusted_price = df['unit_price'] * price_change_multiplier
setAdjustedVolume(price_change_val, df['incr_sales'], df['incr_cvr'], df['units_sold'])
adjusted_volume = df['adjusted_volume']

sales_vars = LpVariable.dicts("Sales",products,0,cat='Continuous')

# %%
def setAdjustedVolume(price_change_val, incr_sales, incr_cvr, original_units_sold):
    df['perc_incr_units_sold'] = [incr_sales*abs(x) + incr_cvr*abs(x) if x < 0 else 0.05*abs(x) for x in df['price_change_val']]    
    df['adjusted_volume'] = original_units_sold*(1+df['perc_incr_units_sold'])

# %%
min_price = -25
max_price = 50

# %%
prob = LpProblem("PricetOpt",LpMaximize)

adjusted_profit=adjusted_price*adjusted_volume-df['unit_cost']*adjusted_volume

profit = dict(zip(products,adjusted_profit))
price_update = dict(zip(products,price_change_val))

prob += lpSum([profit[i]*sales_vars[i] for i in products]), "Total Profit"

prob += lpSum([price_update[f]*sales_vars[f]  for f in products]) >= min_price, "PriceChangeMin"
prob += lpSum([price_update[f]*sales_vars[f]  for f in products]) <= max_price, "PriceChangeMax"

#prob.writeLP("PricetOpt.lp")
prob.solve()
print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal

# %%
print("The total profit is: ${}".format(round(value(prob.objective),2)))
# Out:
# The total profit is: $33227.33

# %%
for v in prob.variables():
    if v.varValue>0:
        print(v.name, "=", v.varValue)
# Out:
# Sales_204 = 251.25628

# %%
prob
# Out:
# PricetOpt:
# MAXIMIZE
# 13.273772849999993*Sales_1 + 35.845145400000035*Sales_10 + 52.78806659999998*Sales_100 + 1.6314732300000006*Sales_101 + 31.313600744999995*Sales_102 + 5.431511100000002*Sales_103 + 28.021971705000013*Sales_104 + 11.226806190000005*Sales_105 + 37.38976293*Sales_106 + 117.90156300000001*Sales_107 + 59.68562112000001*Sales_108 + 7.597045890000004*Sales_109 + 15.583124520000005*Sales_11 + 31.92411552*Sales_110 + 45.8537499*Sales_111 + 34.25911991999999*Sales_112 + 43.84011159000002*Sales_113 + 11.380621575*Sales_114 + 40.18035577500001*Sales_115 + 27.365605200000005*Sales_116 + 1.8118502999999997*Sales_117 + 46.34660550000001*Sales_118 + 9.528575265000004*Sales_119 + 81.48781575000004*Sales_12 + 9.265281300000002*Sales_120 + 27.173209725000007*Sales_121 + 6.484686960000001*Sales_122 + 81.27905908500001*Sales_123 + 71.76260322000002*Sales_124 + 9.010975890000005*Sales_125 + 43.27352964000001*Sales_126 + 10.439045190000002*Sales_127 + 8.25028155*Sales_128 + 11.053902750000006*Sales_129 + 1.8922423200000003*Sales_13 + 12.661743150000007*Sales_130 + 50.26965528000001*Sales_131 + 37.25220774000002*Sales_132 + 60.708700470000025*Sales_133 + 91.37664017999998*Sales_134 + 16.750222739999998*Sales_135 + 1.5520911600000002*Sales_136 + 35.136867464999995*Sales_137 + 92.76673536000001*Sales_138 + 28.531491479999993*Sales_139 + 4.166346735000001*Sales_14 + 11.065012200000005*Sales_140 + 23.205419160000005*Sales_141 + 57.79863053999998*Sales_142 + 42.06714436499999*Sales_143 + 16.04527764000001*Sales_144 + 50.04403245*Sales_145 + 4.025660700000003*Sales_146 + 88.84146368999998*Sales_147 + 70.05821159999999*Sales_148 + 11.375571824999994*Sales_149 + 60.51337614000002*Sales_15 + 11.772482175*Sales_150 + 11.72430756*Sales_151 + 79.136955135*Sales_152 + 46.915409340000025*Sales_153 + 3.8608368600000027*Sales_154 + 39.13111871999999*Sales_155 + 28.207903499999993*Sales_156 + 33.242504249999996*Sales_157 + 11.135405714999997*Sales_158 + 19.896216990000013*Sales_159 + 18.536622299999998*Sales_16 + 67.73381167500001*Sales_160 + 44.768558625*Sales_161 + 8.635678470000002*Sales_162 + 40.87035361500001*Sales_163 + 27.05211672*Sales_164 + 7.57906878*Sales_165 + 60.91008450000001*Sales_166 + 2.5147755000000007*Sales_167 + 40.48788555*Sales_168 + 82.74641543999999*Sales_169 + 88.02572707500002*Sales_17 + 4.833620700000001*Sales_170 + 2.9001724199999996*Sales_171 + 9.157721625*Sales_172 + 48.66444075*Sales_173 + 23.351154945000005*Sales_174 + 52.57395720000001*Sales_175 + 17.036240579999998*Sales_176 + 33.298758465000006*Sales_177 + 41.0686068*Sales_178 + 23.349034049999986*Sales_179 + 39.82434840000002*Sales_18 + 70.04387030999999*Sales_180 + 32.825394900000006*Sales_181 + 4.826551050000003*Sales_182 + 57.09368544000003*Sales_183 + 26.833967520000016*Sales_184 + 29.088680894999996*Sales_185 + 101.67631227000001*Sales_186 + 6.348545699999999*Sales_187 + 1.8942622200000003*Sales_188 + 1.9907124450000016*Sales_189 + 9.190948980000002*Sales_19 + 14.482683000000009*Sales_190 + 9.54463347*Sales_191 + 21.166532099999994*Sales_192 + 19.634942925000004*Sales_193 + 2.256026310000001*Sales_194 + 2.701212270000001*Sales_195 + 28.212953250000005*Sales_196 + 18.014882130000004*Sales_197 + 7.12075347*Sales_198 + 21.909552315*Sales_199 + 14.02860948*Sales_2 + 0.8853221700000002*Sales_20 + 8.282397960000004*Sales_200 + 54.685156680000006*Sales_201 + 7.607650364999998*Sales_202 + 36.13712194499999*Sales_203 + 132.244771905*Sales_204 + 5.431511099999998*Sales_205 + 7.250431050000003*Sales_206 + 31.028693850000003*Sales_207 + 19.035032625*Sales_208 + 11.883071700000006*Sales_209 + 8.762831175000002*Sales_21 + 16.631351625*Sales_210 + 24.81628941000001*Sales_211 + 27.150586844999992*Sales_212 + 25.66141556999999*Sales_213 + 16.122841800000007*Sales_214 + 94.00372212000002*Sales_215 + 58.94391384000002*Sales_216 + 14.602261080000012*Sales_217 + 85.98936489000002*Sales_218 + 66.82182682500002*Sales_219 + 68.93666212500005*Sales_22 + 56.75908900500002*Sales_220 + 44.117847840000024 ...
# SUBJECT TO
# PriceChangeMin: 0.199 Sales_1 + 0.199 Sales_10 + 0.199 Sales_100
#  + 0.199 Sales_101 + 0.199 Sales_102 + 0.199 Sales_103 + 0.199 Sales_104
#  + 0.199 Sales_105 + 0.199 Sales_106 + 0.199 Sales_107 + 0.199 Sales_108
#  + 0.199 Sales_109 + 0.199 Sales_11 + 0.199 Sales_110 + 0.199 Sales_111
#  + 0.199 Sales_112 + 0.199 Sales_113 + 0.199 Sales_114 + 0.199 Sales_115
#  + 0.199 Sales_116 + 0.199 Sales_117 + 0.199 Sales_118 + 0.199 Sales_119
#  + 0.199 Sales_12 + 0.199 Sales_120 + 0.199 Sales_121 + 0.199 Sales_122
#  + 0.199 Sales_123 + 0.199 Sales_124 + 0.199 Sales_125 + 0.199 Sales_126
#  + 0.199 Sales_127 + 0.199 Sales_128 + 0.199 Sales_129 + 0.199 Sales_13
#  + 0.199 Sales_130 + 0.199 Sales_131 + 0.199 Sales_132 + 0.199 Sales_133
#  + 0.199 Sales_134 + 0.199 Sales_135 + 0.199 Sales_136 + 0.199 Sales_137
#  + 0.199 Sales_138 + 0.199 Sales_139 + 0.199 Sales_14 + 0.199 Sales_140
#  + 0.199 Sales_141 + 0.199 Sales_142 + 0.199 Sales_143 + 0.199 Sales_144
#  + 0.199 Sales_145 + 0.199 Sales_146 + 0.199 Sales_147 + 0.199 Sales_148
#  + 0.199 Sales_149 + 0.199 Sales_15 + 0.199 Sales_150 + 0.199 Sales_151
#  + 0.199 Sales_152 + 0.199 Sales_153 + 0.199 Sales_154 + 0.199 Sales_155
#  + 0.199 Sales_156 + 0.199 Sales_157 + 0.199 Sales_158 + 0.199 Sales_159
#  + 0.199 Sales_16 + 0.199 Sales_160 + 0.199 Sales_161 + 0.199 Sales_162
#  + 0.199 Sales_163 + 0.199 Sales_164 + 0.199 Sales_165 + 0.199 Sales_166
#  + 0.199 Sales_167 + 0.199 Sales_168 + 0.199 Sales_169 + 0.199 Sales_17
#  + 0.199 Sales_170 + 0.199 Sales_171 + 0.199 Sales_172 + 0.199 Sales_173
#  + 0.199 Sales_174 + 0.199 Sales_175 + 0.199 Sales_176 + 0.199 Sales_177
#  + 0.199 Sales_178 + 0.199 Sales_179 + 0.199 Sales_18 + 0.199 Sales_180
#  + 0.199 Sales_181 + 0.199 Sales_182 + 0.199 Sales_183 + 0.199 Sales_184
#  + 0.199 Sales_185 + 0.199 Sales_186 + 0.199 Sales_187 + 0.199 Sales_188
#  + 0.199 Sales_189 + 0.199 Sales_19 + 0.199 Sales_190 + 0.199 Sales_191
#  + 0.199 Sales_192 + 0.199 Sales_193 + 0.199 Sales_194 + 0.199 Sales_195
#  + 0.199 Sales_196 + 0.199 Sales_197 + 0.199 Sales_198 + 0.199 Sales_199
#  + 0.199 Sales_2 + 0.199 Sales_20 + 0.199 Sales_200 + 0.199 Sales_201
#  + 0.199 Sales_202 + 0.199 Sales_203 + 0.199 Sales_204 + 0.199 Sales_205
#  + 0.199 Sales_206 + 0.199 Sales_207 + 0.199 Sales_208 + 0.199 Sales_209
#  + 0.199 Sales_21 + 0.199 Sales_210 + 0.199 Sales_211 + 0.199 Sales_212
#  + 0.199 Sales_213 + 0.199 Sales_214 + 0.199 Sales_215 + 0.199 Sales_216
#  + 0.199 Sales_217 + 0.199 Sales_218 + 0.199 Sales_219 + 0.199 Sales_22
#  + 0.199 Sales_220 + 0.199 Sales_221 + 0.199 Sales_222 + 0.199 Sales_223
#  + 0.199 Sales_224 + 0.199 Sales_225 + 0.199 Sales_226 + 0.199 Sales_227
#  + 0.199 Sales_228 + 0.199 Sales_229 + 0.199 Sales_23 + 0.199 Sales_230
#  + 0.199 Sales_231 + 0.199 Sales_232 + 0.199 Sales_233 + 0.199 Sales_234
#  + 0.199 Sales_235 + 0.199 Sales_236 + 0.199 Sales_237 + 0.199 Sales_238
#  + 0.199 Sales_239 + 0.199 Sales_24 + 0.199 Sales_240 + 0.199 Sales_241
#  + 0.199 Sales_242 + 0.199 Sales_243 + 0.199 Sales_244 + 0.199 Sales_245
#  + 0.199 Sales_246 + 0.199 Sales_247 + 0.199 Sales_248 + 0.199 Sales_249
#  + 0.199 Sales_25 + 0.199 Sales_250 + 0.199 Sales_26 + 0.199 Sales_27
#  + 0.199 Sales_28 + 0.199 Sales_29 + 0.199 Sales_3 + 0.199 Sales_30
#  + 0.199 Sales_31 + 0.199 Sales_32 + 0.199 Sales_33 + 0.199 Sales_34
#  + 0.199 Sales_35 + 0.199 Sales_36 + 0.199 Sales_37 + 0.199 Sales_38
#  + 0.199 Sales_39 + 0.199 Sales_4 + 0.199 Sales_40 + 0.199 Sales_41
#  + 0.199 Sales_42 + 0.199 Sales_43 + 0.199 Sales_44 + 0.199 Sales_45
#  + 0.199 Sales_46 + 0.199 Sales_47 + 0.199 Sales_48 + 0.199 Sales_49
#  + 0.199 Sales_5 + 0.199 Sales_50 + 0.199 Sales_51 + 0.199 Sales_52
#  + 0.199 Sales_53 + 0.199 Sales_54 + 0.199 Sales_55 + 0.199 Sales_56
#  + 0.199 Sales_57 + 0.199 Sales_58 + 0.199 Sales_59 + 0.199 Sales_6
#  + 0.199 Sales_60 + 0.199 Sales_61 + 0.199 Sales_62 + 0.199 Sales_63
#  + 0.199 Sales_64 + 0.199 Sales_65 + 0.199 Sales_66 + 0.199 Sales_67
#  + 0.199 Sales_68 + 0.199 Sales_69 + 0.199 Sales_7 + 0.199 Sales_70
#  + 0.199 Sales_71 + 0.199 Sales_72 + 0.199 Sales_73 + 0.199 Sales_74
#  + 0.199 Sales_75 + 0.199 Sales_76 + 0.199 Sales_77 + 0.199 Sales_78
#  + 0.199 Sales_79 + 0.199 Sales_8 + 0.199 Sales_80 + 0.199 Sales_81
#  + 0.199 Sales_82 + 0.199 Sales_83 + 0.199 Sales_84 + 0.199 Sales_85
#  + 0.199 Sales_86 + 0.199 Sales_87 + 0.199 Sales_88 + 0.199 Sales_89
#  + 0.199 Sales_9 + 0.199 Sales_90 + 0.199 Sales_91 + 0.199 Sales_92
#  + 0.199 Sales_93 + 0.199 Sales_94 + 0.199 Sales_95 + 0.199 Sales_96
#  + 0.199 Sales_97 + 0.199 Sales_98 + 0.199 Sales_99 >= -25
#
# PriceChangeMax: 0.199 Sales_1 + 0.199 Sales_10 + 0.199 Sales_100
#  + 0.199 Sales_101 + 0.199 Sales_102 + 0.199 Sales_103 + 0.199 Sales_104
#  + 0.199 Sales_105 + 0.199 Sales_106 + 0.199 Sales_107 + 0.199 Sales_108
#  + 0.199 Sales_109 + 0.199 Sales_11 + 0.199 Sales_110 + 0.199 Sales_111
#  + 0.199 Sales_112 + 0.199 Sales_113 + 0.199 Sales_114 + 0.199 Sales_115
#  + 0.199 Sales_116 + 0.199 Sales_117 + 0.199 Sales_118 + 0.199 Sales_119
#  + 0.199 Sales_12 + 0.199 Sales_120 + 0.199 Sales_121 + 0.199 Sales_122
#  + 0.199 Sales_123 + 0.199 Sales_124 + 0.199 Sales_125 + 0.199 Sales_126
#  + 0.199 Sales_127 + 0.199 Sales_128 + 0.199 Sales_129 + 0.199 Sales_13
#  + 0.199 Sales_130 + 0.199 Sales_131 + 0.199 Sales_132 + 0.199 Sales_133
#  + 0.199 Sales_134 + 0.199 Sales_135 + 0.199 Sales_136 + 0.199 Sales_137
#  + 0.199 Sales_138 + 0.199 Sales_139 + 0.199 Sales_14 + 0.199 Sales_140
#  + 0.199 Sales_141 + 0.199 Sales_142 + 0.199 Sales_143 + 0.199 Sales_144
#  + 0.199 Sales_145 + 0.199 Sales_146 + 0.199 Sales_147 + 0.199 Sales_148
#  + 0.199 Sales_149 + 0.199 Sales_15 + 0.199 Sales_150 + 0.199 Sales_151
#  + 0.199 Sales_152 + 0.199 Sales_153 + 0.199 Sales_154 + 0.199 Sales_155
#  + 0.199 Sales_156 + 0.199 Sales_157 + 0.199 Sales_158 + 0.199 Sales_159
#  + 0.199 Sales_16 + 0.199 Sales_160 + 0.199 Sales_161 + 0.199 Sales_162
#  + 0.199 Sales_163 + 0.199 Sales_164 + 0.199 Sales_165 + 0.199 Sales_166
#  + 0.199 Sales_167 + 0.199 Sales_168 + 0.199 Sales_169 + 0.199 Sales_17
#  + 0.199 Sales_170 + 0.199 Sales_171 + 0.199 Sales_172 + 0.199 Sales_173
#  + 0.199 Sales_174 + 0.199 Sales_175 + 0.199 Sales_176 + 0.199 Sales_177
#  + 0.199 Sales_178 + 0.199 Sales_179 + 0.199 Sales_18 + 0.199 Sales_180
#  + 0.199 Sales_181 + 0.199 Sales_182 + 0.199 Sales_183 + 0.199 Sales_184
#  + 0.199 Sales_185 + 0.199 Sales_186 + 0.199 Sales_187 + 0.199 Sales_188
#  + 0.199 Sales_189 + 0.199 Sales_19 + 0.199 Sales_190 + 0.199 Sales_191
#  + 0.199 Sales_192 + 0.199 Sales_193 + 0.199 Sales_194 + 0.199 Sales_195
#  + 0.199 Sales_196 + 0.199 Sales_197 + 0.199 Sales_198 + 0.199 Sales_199
#  + 0.199 Sales_2 + 0.199 Sales_20 + 0.199 Sales_200 + 0.199 Sales_201
#  + 0.199 Sales_202 + 0.199 Sales_203 + 0.199 Sales_204 + 0.199 Sales_205
#  + 0.199 Sales_206 + 0.199 Sales_207 + 0.199 Sales_208 + 0.199 Sales_209
#  + 0.199 Sales_21 + 0.199 Sales_210 + 0.199 Sales_211 + 0.199 Sales_212
#  + 0.199 Sales_213 + 0.199 Sales_214 + 0.199 Sales_215 + 0.199 Sales_216
#  + 0.199 Sales_217 + 0.199 Sales_218 + 0.199 Sales_219 + 0.199 Sales_22
#  + 0.199 Sales_220 + 0.199 Sales_221 + 0.199 Sales_222 + 0.199 Sales_223
#  + 0.199 Sales_224 + 0.199 Sales_225 + 0.199 Sales_226 + 0.199 Sales_227
#  + 0.199 Sales_228 + 0.199 Sales_229 + 0.199 Sales_23 + 0.199 Sales_230
#  + 0.199 Sales_231 + 0.199 Sales_232 + 0.199 Sales_233 + 0.199 Sales_234
#  + 0.199 Sales_235 + 0.199 Sales_236 + 0.199 Sales_237 + 0.199 Sales_238
#  + 0.199 Sales_239 + 0.199 Sales_24 + 0.199 Sales_240 + 0.199 Sales_241
#  + 0.199 Sales_242 + 0.199 Sales_243 + 0.199 Sales_244 + 0.199 Sales_245
#  + 0.199 Sales_246 + 0.199 Sales_247 + 0.199 Sales_248 + 0.199 Sales_249
#  + 0.199 Sales_25 + 0.199 Sales_250 + 0.199 Sales_26 + 0.199 Sales_27
#  + 0.199 Sales_28 + 0.199 Sales_29 + 0.199 Sales_3 + 0.199 Sales_30
#  + 0.199 Sales_31 + 0.199 Sales_32 + 0.199 Sales_33 + 0.199 Sales_34
#  + 0.199 Sales_35 + 0.199 Sales_36 + 0.199 Sales_37 + 0.199 Sales_38
#  + 0.199 Sales_39 + 0.199 Sales_4 + 0.199 Sales_40 + 0.199 Sales_41
#  + 0.199 Sales_42 + 0.199 Sales_43 + 0.199 Sales_44 + 0.199 Sales_45
#  + 0.199 Sales_46 + 0.199 Sales_47 + 0.199 Sales_48 + 0.199 Sales_49
#  + 0.199 Sales_5 + 0.199 Sales_50 + 0.199 Sales_51 + 0.199 Sales_52
#  + 0.199 Sales_53 + 0.199 Sales_54 + 0.199 Sales_55 + 0.199 Sales_56
#  + 0.199 Sales_57 + 0.199 Sales_58 + 0.199 Sales_59 + 0.199 Sales_6
#  + 0.199 Sales_60 + 0.199 Sales_61 + 0.199 Sales_62 + 0.199 Sales_63
#  + 0.199 Sales_64 + 0.199 Sales_65 + 0.199 Sales_66 + 0.199 Sales_67
#  + 0.199 Sales_68 + 0.199 Sales_69 + 0.199 Sales_7 + 0.199 Sales_70
#  + 0.199 Sales_71 + 0.199 Sales_72 + 0.199 Sales_73 + 0.199 Sales_74
#  + 0.199 Sales_75 + 0.199 Sales_76 + 0.199 Sales_77 + 0.199 Sales_78
#  + 0.199 Sales_79 + 0.199 Sales_8 + 0.199 Sales_80 + 0.199 Sales_81
#  + 0.199 Sales_82 + 0.199 Sales_83 + 0.199 Sales_84 + 0.199 Sales_85
#  + 0.199 Sales_86 + 0.199 Sales_87 + 0.199 Sales_88 + 0.199 Sales_89
#  + 0.199 Sales_9 + 0.199 Sales_90 + 0.199 Sales_91 + 0.199 Sales_92
#  + 0.199 Sales_93 + 0.199 Sales_94 + 0.199 Sales_95 + 0.199 Sales_96
#  + 0.199 Sales_97 + 0.199 Sales_98 + 0.199 Sales_99 <= 50
#
# VARIABLES
# Sales_1 Continuous
# Sales_10 Continuous
# Sales_100 Continuous
# Sales_101 Continuous
# Sales_102 Continuous
# Sales_103 Continuous
# Sales_104 Continuous
# Sales_105 Continuous
# Sales_106 Continuous
# Sales_107 Continuous
# Sales_108 Continuous
# Sales_109 Continuous
# Sales_11 Continuous
# Sales_110 Continuous
# Sales_111 Continuous
# Sales_112 Continuous
# Sales_113 Continuous
# Sales_114 Continuous
# Sales_115 Continuous
# Sales_116 Continuous
# Sales_117 Continuous
# Sales_118 Continuous
# Sales_119 Continuous
# Sales_12 Continuous
# Sales_120 Continuous
# Sales_121 Continuous
# Sales_122 Continuous
# Sales_123 Continuous
# Sales_124 Continuous
# Sales_125 Continuous
# Sales_126 Continuous
# Sales_127 Continuous
# Sales_128 Continuous
# Sales_129 Continuous
# Sales_13 Continuous
# Sales_130 Continuous
# Sales_131 Continuous
# Sales_132 Continuous
# Sales_133 Continuous
# Sales_134 Continuous
# Sales_135 Continuous
# Sales_136 Continuous
# Sales_137 Continuous
# Sales_138 Continuous
# Sales_139 Continuous
# Sales_14 Continuous
# Sales_140 Continuous
# Sales_141 Continuous
# Sales_142 Continuous
# Sales_143 Continuous
# Sales_144 Continuous
# Sales_145 Continuous
# Sales_146 Continuous
# Sales_147 Continuous
# Sales_148 Continuous
# Sales_149 Continuous
# Sales_15 Continuous
# Sales_150 Continuous
# Sales_151 Continuous
# Sales_152 Continuous
# Sales_153 Continuous
# Sales_154 Continuous
# Sales_155 Continuous
# Sales_156 Continuous
# Sales_157 Continuous
# Sales_158 Continuous
# Sales_159 Continuous
# Sales_16 Continuous
# Sales_160 Continuous
# Sales_161 Continuous
# Sales_162 Continuous
# Sales_163 Continuous
# Sales_164 Continuous
# Sales_165 Continuous
# Sales_166 Continuous
# Sales_167 Continuous
# Sales_168 Continuous
# Sales_169 Continuous
# Sales_17 Continuous
# Sales_170 Continuous
# Sales_171 Continuous
# Sales_172 Continuous
# Sales_173 Continuous
# Sales_174 Continuous
# Sales_175 Continuous
# Sales_176 Continuous
# Sales_177 Continuous
# Sales_178 Continuous
# Sales_179 Continuous
# Sales_18 Continuous
# Sales_180 Continuous
# Sales_181 Continuous
# Sales_182 Continuous
# Sales_183 Continuous
# Sales_184 Continuous
# Sales_185 Continuous
# Sales_186 Continuous
# Sales_187 Continuous
# Sales_188 Continuous
# Sales_189 Continuous
# Sales_19 Continuous
# Sales_190 Continuous
# Sales_191 Continuous
# Sales_192 Continuous
# Sales_193 Continuous
# Sales_194 Continuous
# Sales_195 Continuous
# Sales_196 Continuous
# Sales_197 Continuous
# Sales_198 Continuous
# Sales_199 Continuous
# Sales_2 Continuous
# Sales_20 Continuous
# Sales_200 Continuous
# Sales_201 Continuous
# Sales_202 Continuous
# Sales_203 Continuous
# Sales_204 Continuous
# Sales_205 Continuous
# Sales_206 Continuous
# Sales_207 Continuous
# Sales_208 Continuous
# Sales_209 Continuous
# Sales_21 Continuous
# Sales_210 Continuous
# Sales_211 Continuous
# Sales_212 Continuous
# Sales_213 Continuous
# Sales_214 Continuous
# Sales_215 Continuous
# Sales_216 Continuous
# Sales_217 Continuous
# Sales_218 Continuous
# Sales_219 Continuous
# Sales_22 Continuous
# Sales_220 Continuous
# Sales_221 Continuous
# Sales_222 Continuous
# Sales_223 Continuous
# Sales_224 Continuous
# Sales_225 Continuous
# Sales_226 Continuous
# Sales_227 Continuous
# Sales_228 Continuous
# Sales_229 Continuous
# Sales_23 Continuous
# Sales_230 Continuous
# Sales_231 Continuous
# Sales_232 Continuous
# Sales_233 Continuous
# Sales_234 Continuous
# Sales_235 Continuous
# Sales_236 Continuous
# Sales_237 Continuous
# Sales_238 Continuous
# Sales_239 Continuous
# Sales_24 Continuous
# Sales_240 Continuous
# Sales_241 Continuous
# Sales_242 Continuous
# Sales_243 Continuous
# Sales_244 Continuous
# Sales_245 Continuous
# Sales_246 Continuous
# Sales_247 Continuous
# Sales_248 Continuous
# Sales_249 Continuous
# Sales_25 Continuous
# Sales_250 Continuous
# Sales_26 Continuous
# Sales_27 Continuous
# Sales_28 Continuous
# Sales_29 Continuous
# Sales_3 Continuous
# Sales_30 Continuous
# Sales_31 Continuous
# Sales_32 Continuous
# Sales_33 Continuous
# Sales_34 Continuous
# Sales_35 Continuous
# Sales_36 Continuous
# Sales_37 Continuous
# Sales_38 Continuous
# Sales_39 Continuous
# Sales_4 Continuous
# Sales_40 Continuous
# Sales_41 Continuous
# Sales_42 Continuous
# Sales_43 Continuous
# Sales_44 Continuous
# Sales_45 Continuous
# Sales_46 Continuous
# Sales_47 Continuous
# Sales_48 Continuous
# Sales_49 Continuous
# Sales_5 Continuous
# Sales_50 Continuous
# Sales_51 Continuous
# Sales_52 Continuous
# Sales_53 Continuous
# Sales_54 Continuous
# Sales_55 Continuous
# Sales_56 Continuous
# Sales_57 Continuous
# Sales_58 Continuous
# Sales_59 Continuous
# Sales_6 Continuous
# Sales_60 Continuous
# Sales_61 Continuous
# Sales_62 Continuous
# Sales_63 Continuous
# Sales_64 Continuous
# Sales_65 Continuous
# Sales_66 Continuous
# Sales_67 Continuous
# Sales_68 Continuous
# Sales_69 Continuous
# Sales_7 Continuous
# Sales_70 Continuous
# Sales_71 Continuous
# Sales_72 Continuous
# Sales_73 Continuous
# Sales_74 Continuous
# Sales_75 Continuous
# Sales_76 Continuous
# Sales_77 Continuous
# Sales_78 Continuous
# Sales_79 Continuous
# Sales_8 Continuous
# Sales_80 Continuous
# Sales_81 Continuous
# Sales_82 Continuous
# Sales_83 Continuous
# Sales_84 Continuous
# Sales_85 Continuous
# Sales_86 Continuous
# Sales_87 Continuous
# Sales_88 Continuous
# Sales_89 Continuous
# Sales_9 Continuous
# Sales_90 Continuous
# Sales_91 Continuous
# Sales_92 Continuous
# Sales_93 Continuous
# Sales_94 Continuous
# Sales_95 Continuous
# Sales_96 Continuous
# Sales_97 Continuous
# Sales_98 Continuous
# Sales_99 Continuous
